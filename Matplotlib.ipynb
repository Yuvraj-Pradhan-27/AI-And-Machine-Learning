# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as py
import numpy as np

# %%
a1 = np.array([1, 2, 3])

# %%
plt.plot(a1);

# %%
x = [1, 2, 4, 8, 10]
y = [3, 11, 14, 6, 17]
plt.plot(x, y)

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
#marplotlib example workflow

#1. import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1, 2, 4, 8, 10]
y = [3, 6, 12, 24, 48]

#2. Prepare data
fig, ax = plt.subplots(figsize=(10, 10))

#3. Plot the data
ax.plot(x, y)

#4Customise plot
ax.set(title= "simple plot",
       xlabel="x-axis",
       ylabel="y-axis")

#5. Save and show
fig.savefig("images/sample-plot.png")

# %% [markdown]
# Making Figures with Numpy arrays
#
# we want
# * Line Plot
# * Scatter Plot
# * Bar Plot
# * Histogram
# * Sub Plot

# %%
#Create some data
import numpy as np
x1= np.linspace(0, 10, 100)
x1[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#Plot the data
fig, ax = plt.subplots()
ax.plot(x1, x1**2);

# %%
#Use the same data to make a scatter plot
fig, ax = plt.subplots()
ax.scatter(x1, np.exp(x1));

# %%
#Another sub plot
fig, ax = plt.subplots()
ax.scatter(x1, np.sin(x1));

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Butter Prices",
      ylabel = "Price $",
      xlabel = "Butter");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as py
import numpy as np

# %%
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Butter Prices",
      ylabel = "Price $",
      xlabel = "Butter");

# %%
x = np.random.random(1000)
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('$', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale Date
# 0  Toyota  White         150043      4   4000.00 2020-01-01
# 1   Honda    Red          87899      4   5000.00 2020-01-02
# 2  Toyota   Blue          32549      3   7000.00 2020-01-03
# 3     BMW  Black          11179      5  22000.00 2020-01-04
# 4  Nissan  White         213095      4   3500.00 2020-01-05
# 5  Toyota  Green          99213      4   4500.00 2020-01-06
# 6   Honda   Blue          45698      4   7500.00 2020-01-07
# 7   Honda   Blue          54738      4   7000.00 2020-01-08
# 8  Toyota  White          60000      4   6250.00 2020-01-09
# 9  Nissan  White          31600      4   9700.00 2020-01-10

# %%
car_sales["Price"] = car_sales["Price"].str.replace(',', '')
car_sales

car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale Date
# 0  Toyota  White         150043      4   4000.00 2020-01-01
# 1   Honda    Red          87899      4   5000.00 2020-01-02
# 2  Toyota   Blue          32549      3   7000.00 2020-01-03
# 3     BMW  Black          11179      5  22000.00 2020-01-04
# 4  Nissan  White         213095      4   3500.00 2020-01-05
# 5  Toyota  Green          99213      4   4500.00 2020-01-06
# 6   Honda   Blue          45698      4   7500.00 2020-01-07
# 7   Honda   Blue          54738      4   7000.00 2020-01-08
# 8  Toyota  White          60000      4   6250.00 2020-01-09
# 9  Nissan  White          31600      4   9700.00 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
#
# File ~/Desktop/Conda_Environment/env/lib/python3.12/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/Desktop/Conda_Environment/env/lib/python3.12/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~/Desktop/Conda_Environment/env/lib/python3.12/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Desktop/Conda_Environment/env/lib/python3.12/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~/Desktop/Conda_Environment/env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:232, in astype_array_safe(values, dtype, copy, errors)
#     226     msg = (
#     227         f"Expected an instance of {dtype.__name__}, "
#     228         "but got the class instead. Try instantiating 'dtype'."
#     229     )
#     230     raise TypeError(msg)
# --> 232 dtype = pandas_dtype(dtype)
#     233 if isinstance(dtype, NumpyEADtype):
#     234     # Ensure we don't end up with a NumpyExtensionArray
#     235     dtype = dtype.numpy_dtype
#
# File ~/Desktop/Conda_Environment/env/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1636, in pandas_dtype(dtype)
#    1631     with warnings.catch_warnings():
#    1632         # GH#51523 - Series.astype(np.integer) doesn't show
#    1633         # numpy deprecation warning of np.integer
#    1634         # Hence enabling DeprecationWarning
#    1635         warnings.simplefilter("always", DeprecationWarning)
# -> 1636         npdtype = np.dtype(dtype)
#    1637 except SyntaxError as err:
#    1638     # np.dtype uses `eval` which can raise SyntaxError
#    1639     raise TypeError(f"data type '{dtype}' not understood") from err
#
# TypeError: data type 'Prices' not understood

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/
'')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.263781  , 0.01088532, 0.90193085, 0.18061133],
#        [0.09881179, 0.70810839, 0.1864065 , 0.15696795],
#        [0.69226625, 0.26792684, 0.16384013, 0.75441837],
#        [0.9155874 , 0.03598995, 0.73815848, 0.46846853],
#        [0.58196326, 0.59860506, 0.29753959, 0.30583798],
#        [0.68822865, 0.28447883, 0.5015564 , 0.87829962],
#        [0.54891187, 0.38472798, 0.24492341, 0.35055318],
#        [0.23926508, 0.12260311, 0.58758265, 0.58702391],
#        [0.18775898, 0.61459051, 0.83277721, 0.93862458],
#        [0.73948316, 0.46383342, 0.33685014, 0.83511393]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.263781  0.010885  0.901931  0.180611
# 1  0.098812  0.708108  0.186406  0.156968
# 2  0.692266  0.267927  0.163840  0.754418
# 3  0.915587  0.035990  0.738158  0.468469
# 4  0.581963  0.598605  0.297540  0.305838
# 5  0.688229  0.284479  0.501556  0.878300
# 6  0.548912  0.384728  0.244923  0.350553
# 7  0.239265  0.122603  0.587583  0.587024
# 8  0.187759  0.614591  0.832777  0.938625
# 9  0.739483  0.463833  0.336850  0.835114

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind='bar');

# %%
car_sales["Odometer (KM)"].plot(kind='hist');

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
#When plotting something quickly, use pyplot
#When plotting something advanced, use OO method

# %%
heart_disease.head
# Out:
# <bound method NDFrame.head of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]>

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#Pyplot mehtod
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target');

# %%
#OO Method
fix, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

#ax.set_xlim([45, 100])

# %%
#OO method from scratch
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle='--')

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                               sharex=True)
                             

#Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])

#Customise ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
        xlabel="Age",
        ylabel="Cholestrol")

#Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax0.axhline(y=over_50["chol"].mean(),
            linestyle='--');

#Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"])

#Customise ax1
ax0.set(title="Heart Disease and Max Heart rate",
        xlabel="Age",
        ylabel="Max heart rate");

#Add a legend to ax0
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
#Styles available in Matploitlib
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8')

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot.hist();

# %%
x = np.random.randn(10, 4)
x
# Out:
# array([[ 1.33672733, -0.35476071, -0.91419828,  1.60797027],
#        [-0.09684839, -1.03316603,  0.38720732,  1.70414193],
#        [ 0.47130872,  1.05165671,  1.07402676, -0.04779756],
#        [ 0.84151258, -0.19669409,  0.92241729, -1.50216941],
#        [-0.48586763, -1.32137194, -0.24880495, -1.01164978],
#        [ 0.20482301, -1.84057805, -2.0658119 ,  2.26562328],
#        [ 1.34382894,  0.12193926,  1.55974158, -1.02928118],
#        [-0.1470246 ,  0.41287594, -0.47259526,  0.76264642],
#        [-0.35208054,  0.27913097,  0.53804236, -0.96493388],
#        [-0.12542173,  1.01689392, -0.08075516, -1.02497219]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  1.336727 -0.354761 -0.914198  1.607970
# 1 -0.096848 -1.033166  0.387207  1.704142
# 2  0.471309  1.051657  1.074027 -0.047798
# 3  0.841513 -0.196694  0.922417 -1.502169
# 4 -0.485868 -1.321372 -0.248805 -1.011650
# 5  0.204823 -1.840578 -2.065812  2.265623
# 6  1.343829  0.121939  1.559742 -1.029281
# 7 -0.147025  0.412876 -0.472595  0.762646
# 8 -0.352081  0.279131  0.538042 -0.964934
# 9 -0.125422  1.016894 -0.080755 -1.024972

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
#Customise our plot
ax = df.plot(kind='bar')

# Add some labels and a title
ax.set(title="Random Number Bar Graph From DataFrame",
       xlabel="Row number",
       ylabel="Random number")
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-v0_8-whitegrid')

#OO method from scratch
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"],
                    cmap="winter")

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle='--')

# %%
## After adding in different x & y limitations

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Set the x axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');
